# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Users/bhatt/OneDrive/Desktop/whisper-main/Arirlines Dataset/Invistico_Airline.csv')

# %%
data
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0          satisfied     Loyal Customer   65  Personal Travel       Eco
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 2          satisfied     Loyal Customer   15  Personal Travel       Eco
# 3          satisfied     Loyal Customer   60  Personal Travel       Eco
# 4          satisfied     Loyal Customer   70  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
data.isna().sum()
# Out:
# satisfaction                           0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
data['Arrival Delay in Minutes'].fillna(data['Arrival Delay in Minutes'].median(), inplace = True)

# %%
data.isna().sum()
# Out:
# satisfaction                         0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
data
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0          satisfied     Loyal Customer   65  Personal Travel       Eco
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 2          satisfied     Loyal Customer   15  Personal Travel       Eco
# 3          satisfied     Loyal Customer   60  Personal Travel       Eco
# 4          satisfied     Loyal Customer   70  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
data['satisfaction'] = np.where(data['satisfaction'] == 'satisfied', 1, 0)
data['Customer Type'] = np.where(data['Customer Type'] == 'Loyal Customer', 1, 0)
data['Type of Travel'] = np.where(data['Type of Travel'] == 'Personal Travel', 1, 0)

# %%
data
# Out:
#         satisfaction  Customer Type  Age  Type of Travel     Class  \
# 0                  1              1   65               1       Eco
# 1                  1              1   47               1  Business
# 2                  1              1   15               1       Eco
# 3                  1              1   60               1       Eco
# 4                  1              1   70               1       Eco
# ...              ...            ...  ...             ...       ...
# 129875             1              0   29               1       Eco
# 129876             0              0   63               1  Business
# 129877             0              0   69               1       Eco
# 129878             0              0   66               1       Eco
# 129879             0              0   38               1       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                   265             0                                  0
# ...

# %%
data = pd.get_dummies(data, columns=['Class'])

# %%
data
# Out:
#         satisfaction  Customer Type  Age  Type of Travel  Flight Distance  \
# 0                  1              1   65               1              265
# 1                  1              1   47               1             2464
# 2                  1              1   15               1             2138
# 3                  1              1   60               1              623
# 4                  1              1   70               1              354
# ...              ...            ...  ...             ...              ...
# 129875             1              0   29               1             1731
# 129876             0              0   63               1             2087
# 129877             0              0   69               1             2320
# 129878             0              0   66               1             2450
# 129879             0              0   38               1             4307
#
#         Seat comfort  Departure/Arrival time convenient  Food and drink  \
# ...

# %%
label = data['satisfaction']
data.drop('satisfaction', axis = 1)
# Out:
#         Customer Type  Age  Type of Travel  Flight Distance  Seat comfort  \
# 0                   1   65               1              265             0
# 1                   1   47               1             2464             0
# 2                   1   15               1             2138             0
# 3                   1   60               1              623             0
# 4                   1   70               1              354             0
# ...               ...  ...             ...              ...           ...
# 129875              0   29               1             1731             5
# 129876              0   63               1             2087             2
# 129877              0   69               1             2320             3
# 129878              0   66               1             2450             3
# 129879              0   38               1             4307             3
#
#         Departure/Arrival time convenient  Food and drink  Gate location  \
# ...

# %%
data = data.values
label = label.values

# %%
u = np.mean(data, axis = 0)
std = np.std(data, axis = 0)

# %%
data = (data - u)/std

# %%
data
# Out:
# array([[ 0.90942674,  0.47342178,  1.69135082, ..., -0.95806953,
#          1.10790047, -0.27949898],
#        [ 0.90942674,  0.47342178,  0.50081965, ...,  1.04376558,
#         -0.90260816, -0.27949898],
#        [ 0.90942674,  0.47342178, -1.61568021, ..., -0.95806953,
#          1.10790047, -0.27949898],
#        ...,
#        [-1.0995938 , -2.11228136,  1.9559133 , ..., -0.95806953,
#          1.10790047, -0.27949898],
#        [-1.0995938 , -2.11228136,  1.75749144, ..., -0.95806953,
#          1.10790047, -0.27949898],
#        [-1.0995938 , -2.11228136, -0.09444593, ..., -0.95806953,
#          1.10790047, -0.27949898]])

# %%
ones = np.ones((data.shape[0], 1))
data = np.hstack((ones, data))
print(data.shape)
# Out:
# (129880, 25)

# %%
split = 0.8

X_train = data[:int(data.shape[0]*split), :]
X_test = data[int(data.shape[0]*split):, :]

# %%
split = 0.8

Y_train = label[:int(label.shape[0]*split)]
Y_test = label[int(label.shape[0]*split):]

# %%
print(X_test.shape, Y_test.shape, X_train.shape, Y_train.shape)
# Out:
# (25976, 25) (25976,) (103904, 25) (103904,)

# %%
def sigmoid(X):
    return 1/(1 + np.exp(-X))

# %%
def hypothesis(X, theta):
    return sigmoid(np.dot(X, theta))

# %%
def cost(X, Y, theta):
    hx = hypothesis(X, theta)
    loss = np.mean(Y*np.log(hx) + (1-Y)*np.log(1-hx))
    return -1*loss

# %%
def gradient(X, Y, theta):
    y_p = hypothesis(X, theta)
    grad = np.dot(X.T, (Y - y_p))
    return grad/X.shape[0]

# %%
def gradient_descent(X, Y):
    theta = np.zeros((X.shape[1], ))
    
    max_epochs = 5000
    epoch_loss = []
    lr = 0.00388
    
    for i in range(max_epochs):
        print('\rON:', i, end = '\r')
        grad = gradient(X, Y, theta)
        
        loss = cost(X, Y, theta)
        epoch_loss.append(loss)
        
        theta = theta + lr*grad
        
    return theta, epoch_loss

# %%
theta, epoch_loss = gradient_descent(X_train, Y_train)
# Out:
# ON: 4999

# %%
epoch_loss[-10:]
# Out:
# [0.05637158441536006,
#  0.05636040123799176,
#  0.056349222286272156,
#  0.056338047557883866,
#  0.056326877050511266,
#  0.056315710761840346,
#  0.056304548689558725,
#  0.05629339083135568,
#  0.05628223718492216,
#  0.056271087747950733]

# %%
plt.plot(epoch_loss)
